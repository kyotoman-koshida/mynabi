# %% [markdown]
# DART用のシート

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import scipy as sp
import lightgbm as lgb
import category_encoders as ce
# import mojimoji
import re
from cmath import nan
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
import optuna
from sklearn.metrics import mean_squared_error
import japanize_matplotlib

# %%
###訓練データの読み込み
house_age = pd.read_csv('house_age.csv')
area_size = pd.read_csv('area_size.csv')
room_arrange = pd.read_csv('room_arrange.csv')
contract_span = pd.read_csv('contract_span.csv')#欠損値をゼロ埋めした契約期間
contract_span2 = pd.read_csv('contract_span2.csv')#欠損値を欠損値のままにした契約期間
reg_rent = pd.read_csv('reg_rent.csv')
floor_scores = pd.read_csv('floor_scores.csv')#「所在階」と「全体の階数」が連動して欠損値になる場合のある「所在階」
floor_scores2 = pd.read_csv('floor_scores2.csv')#「所在階」と「全体の階数」が独立している「所在階」
Floor_scores = pd.read_csv('capital_floor_scores.csv')#「所在階」と「全体の階数」が連動して欠損値になる場合のある「全体の階数」
Floor_scores2 = pd.read_csv('capital_floor_scores2.csv')#「所在階」と「全体の階数」が独立している「全体の階数」
stations = pd.read_csv('stations.csv')
minits = pd.read_csv('minits.csv')
addresses = pd.read_csv('addresses.csv')
room_arrange = pd.read_csv('room_arrange.csv')
buildings = pd.read_csv('buildings.csv')

rent = pd.read_csv('rent.csv')


##テストデータの読み込み
test_house_age = pd.read_csv('test_house_age.csv')
test_area_size = pd.read_csv('test_area_size.csv')
test_room_arrange = pd.read_csv('test_room_arrange.csv')
test_contract_span = pd.read_csv('test_contract_span.csv')
test_contract_span2 = pd.read_csv('test_contract_span2.csv')
test_reg_rent = pd.read_csv('test_reg_rent.csv')
test_floor_scores = pd.read_csv('test_floor_scores.csv')
test_floor_scores2 = pd.read_csv('test_floor_scores2.csv')
test_Floor_scores = pd.read_csv('test_capital_floor_scores.csv')
test_Floor_scores2 = pd.read_csv('test_capital_floor_scores2.csv')
test_stations = pd.read_csv('test_stations.csv')
test_minits = pd.read_csv('test_minits.csv')
test_addresses = pd.read_csv('test_addresses.csv')
test_room_arrange = pd.read_csv('test_room_arrange.csv')
test_buildings = pd.read_csv('test_buildings.csv')

# %% [markdown]
# DARTで契約期間２＆間取り（S以外）

# %%
X_train = pd.concat([house_age, area_size, contract_span2, reg_rent, floor_scores2, Floor_scores2, stations, minits, addresses, room_arrange[["部屋数","L","D","K"]]], axis=1)
y_train = rent

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.3, random_state=0)

X_test = pd.concat([test_house_age, test_area_size, test_contract_span2, test_reg_rent, test_floor_scores2, test_Floor_scores2, test_stations, test_minits, test_addresses, test_room_arrange[["部屋数","L","D","K"]]], axis=1)

category_lists = ['定期借家','最寄り駅', '所在地', 'L', 'D', 'K']
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train)

params = {
    'objective':'regression',
    'boosting_type':'dart',
    'metrics':'rmse',
    'reg_lambda': 2.1600820741402023e-05,
    'max_bin': 556,
    'num_leaves': 126
}

model = lgb.train(
                    params,
                    lgb_train, 
                    valid_sets=[lgb_train, lgb_eval], 
                    verbose_eval=10, 
                    num_boost_round=3000, 
                    early_stopping_rounds=10,
                    categorical_feature = category_lists
                    )

y_pred = model.predict(X_test, num_iteration=model.best_iteration)
# Out:
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['D', 'K', 'L', '定期借家', '所在地', '最寄り駅']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\callback.py:223: UserWarning: Early stopping is not available in dart mode
#   _log_warning('Early stopping is not available in dart mode')
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000910 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2446
# [LightGBM] [Info] Number of data points in the train set: 22029, number of used features: 13
# [LightGBM] [Info] Start training from score 118651.337373
# [10]	training's rmse: 38670.2	valid_1's rmse: 43942.2
# [20]	training's rmse: 23485.3	valid_1's rmse: 32497.3
# [30]	training's rmse: 17625.1	valid_1's rmse: 28275.8
# [40]	training's rmse: 16309.4	valid_1's rmse: 27302.9
# [50]	training's rmse: 20970.1	valid_1's rmse: 30253.9
# [60]	training's rmse: 25043.5	valid_1's rmse: 33199.2
# [70]	training's rmse: 23838.5	valid_1's rmse: 32259.3
# [80]	training's rmse: 18914.7	valid_1's rmse: 28737.2
# [90]	training's rmse: 19417.6	valid_1's rmse: 29136.2
# [100]	training's rmse: 20210.9	valid_1's rmse: 29698.8
# [110]	training's rmse: 26418.5	valid_1's rmse: 34277.6
# [120]	training's rmse: 18450	valid_1's rmse: 28503.1
# [130]	training's rmse: 16484.2	valid_1's rmse: 27240.2
# [140]	training's rmse: 18907.9	valid_1's rmse: 28783.6
# [150]	training's rmse: 17768.4	valid_1's rmse: 28052.4
# [160]	training's rmse: 21915	valid_1's rmse: 30903.4
# [170]	training's rmse: 15929.3	valid_1's rmse: 26776.2
# [180]	training's rmse: 15371.2	valid_1's rmse: 26389.8
# [190]	training's rmse: 13034.9	valid_1's rmse: 24944.8
# [200]	training's rmse: 12815.4	valid_1's rmse: 24809.2
# [210]	training's rmse: 14545.6	valid_1's rmse: 25880
# [220]	training's rmse: 12693.3	valid_1's rmse: 24755.2
# [230]	training's rmse: 12841.2	valid_1's rmse: 24886.4
# [240]	training's rmse: 10798.9	valid_1's rmse: 23686.2
# [250]	training's rmse: 11124.6	valid_1's rmse: 23850.2
# [260]	training's rmse: 10614.5	valid_1's rmse: 23567
# [270]	training's rmse: 9940.12	valid_1's rmse: 23205
# [280]	training's rmse: 10091.2	valid_1's rmse: 23312.1
# [290]	training's rmse: 9638.97	valid_1's rmse: 23046.9
# [300]	training's rmse: 10046.1	valid_1's rmse: 23279.4
# [310]	training's rmse: 10990.4	valid_1's rmse: 23788.9
# [320]	training's rmse: 9990.4	valid_1's rmse: 23243.8
# [330]	training's rmse: 9853.48	valid_1's rmse: 23199.2
# [340]	training's rmse: 10720.6	valid_1's rmse: 23655.7
# [350]	training's rmse: 9601.93	valid_1's rmse: 23117.4
# [360]	training's rmse: 9426.97	valid_1's rmse: 22997.9
# [370]	training's rmse: 9283.68	valid_1's rmse: 22945.6
# [380]	training's rmse: 8955.7	valid_1's rmse: 22765.8
# [390]	training's rmse: 8383.7	valid_1's rmse: 22503.9
# [400]	training's rmse: 7817.11	valid_1's rmse: 22240.2
# [410]	training's rmse: 7834.96	valid_1's rmse: 22260.4
# [420]	training's rmse: 7904.38	valid_1's rmse: 22304.7
# [430]	training's rmse: 7769.91	valid_1's rmse: 22255.3
# [440]	training's rmse: 7731.62	valid_1's rmse: 22206.1
# [450]	training's rmse: 7183.2	valid_1's rmse: 21990.3
# [460]	training's rmse: 7526.13	valid_1's rmse: 22155.5
# [470]	training's rmse: 7693.84	valid_1's rmse: 22240.3
# [480]	training's rmse: 7431.5	valid_1's rmse: 22108.6
# [490]	training's rmse: 6926.23	valid_1's rmse: 21910.4
# [500]	training's rmse: 6836.08	valid_1's rmse: 21877.1
# [510]	training's rmse: 6630.38	valid_1's rmse: 21808.6
# [520]	training's rmse: 6727.66	valid_1's rmse: 21848.8
# [530]	training's rmse: 6831.66	valid_1's rmse: 21879.7
# [540]	training's rmse: 6804.6	valid_1's rmse: 21860.7
# [550]	training's rmse: 6628.59	valid_1's rmse: 21781.7
# [560]	training's rmse: 6522.52	valid_1's rmse: 21759.9
# [570]	training's rmse: 6890.73	valid_1's rmse: 21912.9
# [580]	training's rmse: 7284.79	valid_1's rmse: 22090.5
# [590]	training's rmse: 7380.99	valid_1's rmse: 22138
# [600]	training's rmse: 7333.08	valid_1's rmse: 22119.9
# [610]	training's rmse: 7094.54	valid_1's rmse: 21988
# [620]	training's rmse: 6504.83	valid_1's rmse: 21737.7
# [630]	training's rmse: 6541.94	valid_1's rmse: 21765.8
# [640]	training's rmse: 6402.87	valid_1's rmse: 21713.9
# [650]	training's rmse: 6492	valid_1's rmse: 21753.5
# [660]	training's rmse: 6446.41	valid_1's rmse: 21734.2
# [670]	training's rmse: 6816.19	valid_1's rmse: 21887.3
# [680]	training's rmse: 6391	valid_1's rmse: 21723.7
# [690]	training's rmse: 6384.69	valid_1's rmse: 21722.8
# [700]	training's rmse: 6156.7	valid_1's rmse: 21650.2
# [710]	training's rmse: 6114.95	valid_1's rmse: 21646.9
# [720]	training's rmse: 6527.33	valid_1's rmse: 21797.6
# [730]	training's rmse: 6149.75	valid_1's rmse: 21661.2
# [740]	training's rmse: 6076.64	valid_1's rmse: 21617
# [750]	training's rmse: 5979.39	valid_1's rmse: 21570.2
# [760]	training's rmse: 5940.05	valid_1's rmse: 21577
# [770]	training's rmse: 6006.94	valid_1's rmse: 21597.7
# [780]	training's rmse: 6050.85	valid_1's rmse: 21628.2
# [790]	training's rmse: 5988.78	valid_1's rmse: 21612
# [800]	training's rmse: 6075.9	valid_1's rmse: 21652.4
# [810]	training's rmse: 6118.88	valid_1's rmse: 21676.1
# [820]	training's rmse: 6001.07	valid_1's rmse: 21621.3
# [830]	training's rmse: 5687.23	valid_1's rmse: 21486.7
# [840]	training's rmse: 5449.59	valid_1's rmse: 21419.4
# [850]	training's rmse: 5454.05	valid_1's rmse: 21422.8
# [860]	training's rmse: 5479.08	valid_1's rmse: 21426.1
# [870]	training's rmse: 5378.98	valid_1's rmse: 21372.4
# [880]	training's rmse: 5683.01	valid_1's rmse: 21484
# [890]	training's rmse: 5359.89	valid_1's rmse: 21350.9
# [900]	training's rmse: 5398.76	valid_1's rmse: 21361.3
# [910]	training's rmse: 5515.23	valid_1's rmse: 21422.6
# [920]	training's rmse: 5717.75	valid_1's rmse: 21501.9
# [930]	training's rmse: 5547.98	valid_1's rmse: 21443.8
# [940]	training's rmse: 5449.43	valid_1's rmse: 21383.4
# [950]	training's rmse: 5325.59	valid_1's rmse: 21340.4
# [960]	training's rmse: 5215.44	valid_1's rmse: 21314.7
# [970]	training's rmse: 5167.19	valid_1's rmse: 21315.7
# [980]	training's rmse: 5170.11	valid_1's rmse: 21301.3
# [990]	training's rmse: 5351.46	valid_1's rmse: 21392.1
# [1000]	training's rmse: 5161.09	valid_1's rmse: 21329.8
# [1010]	training's rmse: 4929.52	valid_1's rmse: 21264.9
# [1020]	training's rmse: 4952.34	valid_1's rmse: 21290.7
# [1030]	training's rmse: 4945.22	valid_1's rmse: 21280.1
# [1040]	training's rmse: 4929.26	valid_1's rmse: 21258.9
# [1050]	training's rmse: 4873.3	valid_1's rmse: 21248.6
# [1060]	training's rmse: 5081.02	valid_1's rmse: 21320.5
# [1070]	training's rmse: 5094.14	valid_1's rmse: 21330.9
# [1080]	training's rmse: 4987.03	valid_1's rmse: 21273.3
# [1090]	training's rmse: 5144.15	valid_1's rmse: 21321.6
# [1100]	training's rmse: 4907.98	valid_1's rmse: 21240.1
# [1110]	training's rmse: 5153.48	valid_1's rmse: 21324.6
# [1120]	training's rmse: 5580.15	valid_1's rmse: 21466.1
# [1130]	training's rmse: 5028.75	valid_1's rmse: 21302.1
# [1140]	training's rmse: 4917.84	valid_1's rmse: 21269.5
# [1150]	training's rmse: 4855.05	valid_1's rmse: 21249.2
# [1160]	training's rmse: 4882.38	valid_1's rmse: 21255.6
# [1170]	training's rmse: 5028.34	valid_1's rmse: 21286.8
# [1180]	training's rmse: 5135.08	valid_1's rmse: 21324
# [1190]	training's rmse: 4953.95	valid_1's rmse: 21247
# [1200]	training's rmse: 4841.16	valid_1's rmse: 21215.3
# [1210]	training's rmse: 4521.13	valid_1's rmse: 21135.2
# [1220]	training's rmse: 4442.47	valid_1's rmse: 21109.7
# [1230]	training's rmse: 4443.38	valid_1's rmse: 21107.9
# [1240]	training's rmse: 4675.2	valid_1's rmse: 21184.6
# [1250]	training's rmse: 4619.97	valid_1's rmse: 21169.5
# [1260]	training's rmse: 4552.11	valid_1's rmse: 21135.6
# [1270]	training's rmse: 4598.99	valid_1's rmse: 21164
# [1280]	training's rmse: 4719.78	valid_1's rmse: 21204.2
# [1290]	training's rmse: 4982.88	valid_1's rmse: 21290.4
# [1300]	training's rmse: 4604.47	valid_1's rmse: 21169.6
# [1310]	training's rmse: 4416.73	valid_1's rmse: 21099.2
# [1320]	training's rmse: 4530.12	valid_1's rmse: 21143.8
# [1330]	training's rmse: 4268.43	valid_1's rmse: 21073.5
# [1340]	training's rmse: 4414.25	valid_1's rmse: 21132.6
# [1350]	training's rmse: 4545.82	valid_1's rmse: 21169.1
# [1360]	training's rmse: 4322.42	valid_1's rmse: 21091.9
# [1370]	training's rmse: 4070.79	valid_1's rmse: 21028.2
# [1380]	training's rmse: 4129.02	valid_1's rmse: 21036.3
# [1390]	training's rmse: 4174.25	valid_1's rmse: 21059.4
# [1400]	training's rmse: 4083.38	valid_1's rmse: 21028.5
# [1410]	training's rmse: 4150.25	valid_1's rmse: 21050.2
# [1420]	training's rmse: 4197.86	valid_1's rmse: 21078.5
# [1430]	training's rmse: 4164.57	valid_1's rmse: 21059.4
# [1440]	training's rmse: 4274.88	valid_1's rmse: 21098.3
# [1450]	training's rmse: 4270.18	valid_1's rmse: 21095.8
# [1460]	training's rmse: 4055.97	valid_1's rmse: 21009.9
# [1470]	training's rmse: 4094.31	valid_1's rmse: 21031.9
# [1480]	training's rmse: 4186.84	valid_1's rmse: 21058.6
# [1490]	training's rmse: 4219.36	valid_1's rmse: 21063
# [1500]	training's rmse: 4306.18	valid_1's rmse: 21089.3
# [1510]	training's rmse: 4502.99	valid_1's rmse: 21150.9
# [1520]	training's rmse: 4424.94	valid_1's rmse: 21145.2
# [1530]	training's rmse: 4378.36	valid_1's rmse: 21129.6
# [1540]	training's rmse: 4261	valid_1's rmse: 21087
# [1550]	training's rmse: 4112	valid_1's rmse: 21054.4
# [1560]	training's rmse: 4065.73	valid_1's rmse: 21053.6
# [1570]	training's rmse: 3971.69	valid_1's rmse: 21012.2
# [1580]	training's rmse: 3801.89	valid_1's rmse: 20942.7
# [1590]	training's rmse: 3755.84	valid_1's rmse: 20923.1
# [1600]	training's rmse: 3743.43	valid_1's rmse: 20923.1
# [1610]	training's rmse: 3794.71	valid_1's rmse: 20939
# [1620]	training's rmse: 3949.68	valid_1's rmse: 20975.3
# [1630]	training's rmse: 3801	valid_1's rmse: 20917.8
# [1640]	training's rmse: 3742.06	valid_1's rmse: 20919.1
# [1650]	training's rmse: 4112.98	valid_1's rmse: 21018.5
# [1660]	training's rmse: 3831.59	valid_1's rmse: 20933.3
# [1670]	training's rmse: 3756.56	valid_1's rmse: 20918.2
# [1680]	training's rmse: 3587.94	valid_1's rmse: 20882.1
# [1690]	training's rmse: 3523.44	valid_1's rmse: 20865.1
# [1700]	training's rmse: 3486.14	valid_1's rmse: 20863.5
# [1710]	training's rmse: 3493.73	valid_1's rmse: 20865.4
# [1720]	training's rmse: 3541.89	valid_1's rmse: 20877.7
# [1730]	training's rmse: 3489.62	valid_1's rmse: 20857.1
# [1740]	training's rmse: 3513.7	valid_1's rmse: 20865.1
# [1750]	training's rmse: 3447.25	valid_1's rmse: 20835.8
# [1760]	training's rmse: 3481.87	valid_1's rmse: 20843.7
# [1770]	training's rmse: 3453.2	valid_1's rmse: 20829.7
# [1780]	training's rmse: 3467.75	valid_1's rmse: 20840
# [1790]	training's rmse: 3386.79	valid_1's rmse: 20806.5
# [1800]	training's rmse: 3543.43	valid_1's rmse: 20856
# [1810]	training's rmse: 3326.91	valid_1's rmse: 20799.1
# [1820]	training's rmse: 3267.84	valid_1's rmse: 20790
# [1830]	training's rmse: 3368.08	valid_1's rmse: 20815.1
# [1840]	training's rmse: 3355.19	valid_1's rmse: 20808.1
# [1850]	training's rmse: 3328.56	valid_1's rmse: 20797.5
# [1860]	training's rmse: 3405.21	valid_1's rmse: 20822.8
# [1870]	training's rmse: 3315.15	valid_1's rmse: 20797.2
# [1880]	training's rmse: 3373.97	valid_1's rmse: 20812.8
# [1890]	training's rmse: 3475.45	valid_1's rmse: 20839
# [1900]	training's rmse: 3255.01	valid_1's rmse: 20792.7
# [1910]	training's rmse: 3340.39	valid_1's rmse: 20810.1
# [1920]	training's rmse: 3558.82	valid_1's rmse: 20859.1
# [1930]	training's rmse: 3523.31	valid_1's rmse: 20856.3
# [1940]	training's rmse: 3306.34	valid_1's rmse: 20784.6
# [1950]	training's rmse: 3186.36	valid_1's rmse: 20757
# [1960]	training's rmse: 3270.15	valid_1's rmse: 20778.7
# [1970]	training's rmse: 3249.69	valid_1's rmse: 20772.3
# [1980]	training's rmse: 3216.98	valid_1's rmse: 20752.6
# [1990]	training's rmse: 3298.06	valid_1's rmse: 20783.5
# [2000]	training's rmse: 3202.45	valid_1's rmse: 20747.2
# [2010]	training's rmse: 3214.29	valid_1's rmse: 20765.8
# [2020]	training's rmse: 3016.62	valid_1's rmse: 20709.8
# [2030]	training's rmse: 3017.53	valid_1's rmse: 20707.6
# [2040]	training's rmse: 3013.13	valid_1's rmse: 20694.8
# [2050]	training's rmse: 3053.57	valid_1's rmse: 20707.7
# [2060]	training's rmse: 3056.62	valid_1's rmse: 20701.8
# [2070]	training's rmse: 3272.3	valid_1's rmse: 20753.2
# [2080]	training's rmse: 3047.88	valid_1's rmse: 20691.7
# [2090]	training's rmse: 2936.64	valid_1's rmse: 20666.5
# [2100]	training's rmse: 2861.3	valid_1's rmse: 20642.1
# [2110]	training's rmse: 2945.79	valid_1's rmse: 20665.9
# [2120]	training's rmse: 2990.19	valid_1's rmse: 20671
# [2130]	training's rmse: 3071.31	valid_1's rmse: 20689.7
# [2140]	training's rmse: 3006.86	valid_1's rmse: 20671.5
# [2150]	training's rmse: 2965.97	valid_1's rmse: 20657.2
# [2160]	training's rmse: 2903.71	valid_1's rmse: 20648.3
# [2170]	training's rmse: 2939.64	valid_1's rmse: 20655.3
# [2180]	training's rmse: 2852.6	valid_1's rmse: 20636.8
# [2190]	training's rmse: 2849.07	valid_1's rmse: 20643.8
# [2200]	training's rmse: 2776.84	valid_1's rmse: 20612.8
# [2210]	training's rmse: 2888.26	valid_1's rmse: 20641.2
# [2220]	training's rmse: 2825.72	valid_1's rmse: 20632.9
# [2230]	training's rmse: 2924.9	valid_1's rmse: 20657.8
# [2240]	training's rmse: 2911.01	valid_1's rmse: 20651.7
# [2250]	training's rmse: 2773.93	valid_1's rmse: 20614.8
# [2260]	training's rmse: 2631.54	valid_1's rmse: 20577.1
# [2270]	training's rmse: 2681.32	valid_1's rmse: 20589.9
# [2280]	training's rmse: 2722.76	valid_1's rmse: 20599.1
# [2290]	training's rmse: 2608.48	valid_1's rmse: 20566
# [2300]	training's rmse: 2619.48	valid_1's rmse: 20572.5
# [2310]	training's rmse: 2660.49	valid_1's rmse: 20582.6
# [2320]	training's rmse: 2621.21	valid_1's rmse: 20564.8
# [2330]	training's rmse: 2586.42	valid_1's rmse: 20554.1
# [2340]	training's rmse: 2593.66	valid_1's rmse: 20562.1
# [2350]	training's rmse: 2575.46	valid_1's rmse: 20556.3
# [2360]	training's rmse: 2486.57	valid_1's rmse: 20533
# [2370]	training's rmse: 2501.04	valid_1's rmse: 20541
# [2380]	training's rmse: 2477.54	valid_1's rmse: 20536.3
# [2390]	training's rmse: 2453.41	valid_1's rmse: 20520.1
# [2400]	training's rmse: 2480.1	valid_1's rmse: 20529.1
# [2410]	training's rmse: 2477.87	valid_1's rmse: 20526
# [2420]	training's rmse: 2476.92	valid_1's rmse: 20526.4
# [2430]	training's rmse: 2606.37	valid_1's rmse: 20546
# [2440]	training's rmse: 2565.99	valid_1's rmse: 20535.1
# [2450]	training's rmse: 2548.4	valid_1's rmse: 20535
# [2460]	training's rmse: 2455.96	valid_1's rmse: 20518
# [2470]	training's rmse: 2457.35	valid_1's rmse: 20516.3
# [2480]	training's rmse: 2473.35	valid_1's rmse: 20517.8
# [2490]	training's rmse: 2587.1	valid_1's rmse: 20544.5
# [2500]	training's rmse: 2495.44	valid_1's rmse: 20517.5
# [2510]	training's rmse: 2406.8	valid_1's rmse: 20503.6
# [2520]	training's rmse: 2416.68	valid_1's rmse: 20508.9
# [2530]	training's rmse: 2467.12	valid_1's rmse: 20516.1
# [2540]	training's rmse: 2535.52	valid_1's rmse: 20530.4
# [2550]	training's rmse: 2607.33	valid_1's rmse: 20546.2
# [2560]	training's rmse: 2579.68	valid_1's rmse: 20534
# [2570]	training's rmse: 2561.23	valid_1's rmse: 20530.8
# [2580]	training's rmse: 2520.43	valid_1's rmse: 20513
# [2590]	training's rmse: 2487.57	valid_1's rmse: 20508.1
# [2600]	training's rmse: 2427.46	valid_1's rmse: 20495.3
# [2610]	training's rmse: 2449.89	valid_1's rmse: 20501.9
# [2620]	training's rmse: 2469.7	valid_1's rmse: 20504.4
# [2630]	training's rmse: 2408.69	valid_1's rmse: 20493.6
# [2640]	training's rmse: 2394.34	valid_1's rmse: 20489.2
# [2650]	training's rmse: 2461.45	valid_1's rmse: 20510
# [2660]	training's rmse: 2386.9	valid_1's rmse: 20481.5
# [2670]	training's rmse: 2560.68	valid_1's rmse: 20519.2
# [2680]	training's rmse: 2448.64	valid_1's rmse: 20486.8
# [2690]	training's rmse: 2378.56	valid_1's rmse: 20470.4
# [2700]	training's rmse: 2299.66	valid_1's rmse: 20462.3
# [2710]	training's rmse: 2298.39	valid_1's rmse: 20462.6
# [2720]	training's rmse: 2371.21	valid_1's rmse: 20478.1
# [2730]	training's rmse: 2537.24	valid_1's rmse: 20509
# [2740]	training's rmse: 2595.25	valid_1's rmse: 20518.7
# [2750]	training's rmse: 2488.07	valid_1's rmse: 20499.9
# [2760]	training's rmse: 2600.52	valid_1's rmse: 20526.9
# [2770]	training's rmse: 2620.71	valid_1's rmse: 20533.2
# [2780]	training's rmse: 2461.35	valid_1's rmse: 20492.7
# [2790]	training's rmse: 2511.79	valid_1's rmse: 20495.4
# [2800]	training's rmse: 2422.32	valid_1's rmse: 20489
# [2810]	training's rmse: 2440.82	valid_1's rmse: 20491
# [2820]	training's rmse: 2404.68	valid_1's rmse: 20481.7
# [2830]	training's rmse: 2414.11	valid_1's rmse: 20478.9
# [2840]	training's rmse: 2430.05	valid_1's rmse: 20481.5
# [2850]	training's rmse: 2368.97	valid_1's rmse: 20464.5
# [2860]	training's rmse: 2392.67	valid_1's rmse: 20473.4
# [2870]	training's rmse: 2330.05	valid_1's rmse: 20464.2
# [2880]	training's rmse: 2265.73	valid_1's rmse: 20446.6
# [2890]	training's rmse: 2262.87	valid_1's rmse: 20445.4
# [2900]	training's rmse: 2350.66	valid_1's rmse: 20456.8
# [2910]	training's rmse: 2358.63	valid_1's rmse: 20457.6
# [2920]	training's rmse: 2313.14	valid_1's rmse: 20447.8
# [2930]	training's rmse: 2323.38	valid_1's rmse: 20451.1
# [2940]	training's rmse: 2257.16	valid_1's rmse: 20430.9
# [2950]	training's rmse: 2239.86	valid_1's rmse: 20431
# [2960]	training's rmse: 2291.19	valid_1's rmse: 20450
# [2970]	training's rmse: 2168.98	valid_1's rmse: 20422.9
# [2980]	training's rmse: 2145.06	valid_1's rmse: 20417.8
# [2990]	training's rmse: 2124.37	valid_1's rmse: 20417.1
# [3000]	training's rmse: 2132.12	valid_1's rmse: 20416.3

# %%
df = pd.read_csv('test.csv')
id = df['id']
y_pred = pd.DataFrame(y_pred)
result = pd.concat([id, y_pred],axis=1)
result.to_csv('DART_cs2_nLDK_result.csv',index=False)

# %% [markdown]
# DARTでもそこまでlightGBMと高い相関係数が出る。

# %%
LGBM_cs2_nLD_bld_results = pd.read_csv('LGBM_cs2_nLD_bld_result.csv')
DART_cs2_nLDK_results = pd.read_csv('DART_cs2_nLDK_result.csv')
X = pd.concat([LGBM_cs2_nLD_bld_results['0'],DART_cs2_nLDK_results['0']],axis=1)
X.corr()
# Out:
#           0         0
# 0  1.000000  0.991641
# 0  0.991641  1.000000

# %% [markdown]
# DARTで間取り１＆フル間取り＆建物構造

# %%
X_train = pd.concat([house_age, area_size, contract_span, reg_rent, floor_scores2, Floor_scores2, stations, minits, addresses, room_arrange[["部屋数","L","D","K","S"]],buildings], axis=1)
y_train = rent

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.3, random_state=0)

X_test = pd.concat([test_house_age, test_area_size, test_contract_span, test_reg_rent, test_floor_scores2, test_Floor_scores2, test_stations, test_minits, test_addresses, test_room_arrange[["部屋数","L","D","K","S"]],test_buildings], axis=1)

category_lists = ['定期借家','最寄り駅', '所在地', 'L', 'D', 'K','S','建物構造']
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train)

params = {
    'objective':'regression',
    'boosting_type':'dart',
    'metrics':'rmse',
    'reg_lambda': 2.1600820741402023e-05,
    'max_bin': 556,
    'num_leaves': 126
}

model = lgb.train(
                    params,
                    lgb_train, 
                    valid_sets=[lgb_train, lgb_eval], 
                    verbose_eval=10, 
                    num_boost_round=3000, 
                    early_stopping_rounds=10,
                    categorical_feature = category_lists
                    )

y_pred = model.predict(X_test, num_iteration=model.best_iteration)
# Out:
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['D', 'K', 'L', 'S', '定期借家', '建物構造', '所在地', '最寄り駅']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# c:\Users\koshi\python\signate\mynabi\venv\lib\site-packages\lightgbm\callback.py:223: UserWarning: Early stopping is not available in dart mode
#   _log_warning('Early stopping is not available in dart mode')
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001623 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2452
# [LightGBM] [Info] Number of data points in the train set: 22029, number of used features: 15
# [LightGBM] [Info] Start training from score 118651.337373
# [10]	training's rmse: 38695.7	valid_1's rmse: 43975.5
# [20]	training's rmse: 23437.8	valid_1's rmse: 32297.8
# [30]	training's rmse: 17755.2	valid_1's rmse: 28234.9
# [40]	training's rmse: 16403.2	valid_1's rmse: 27354.8
# [50]	training's rmse: 20983.9	valid_1's rmse: 30349.2
# [60]	training's rmse: 24943.6	valid_1's rmse: 33236.5
# [70]	training's rmse: 23853.4	valid_1's rmse: 32390.4
# [80]	training's rmse: 18820.9	valid_1's rmse: 28850.2
# [90]	training's rmse: 19299.4	valid_1's rmse: 29223.2
# [100]	training's rmse: 20187	valid_1's rmse: 29816
# [110]	training's rmse: 26376.4	valid_1's rmse: 34376.4
# [120]	training's rmse: 18369.1	valid_1's rmse: 28564.5
# [130]	training's rmse: 16442.6	valid_1's rmse: 27371.4
# [140]	training's rmse: 18906.9	valid_1's rmse: 28931.2
# [150]	training's rmse: 17754.2	valid_1's rmse: 28145.2
# [160]	training's rmse: 21843.7	valid_1's rmse: 30965.1
# [170]	training's rmse: 15890.9	valid_1's rmse: 26897.5
# [180]	training's rmse: 15362.1	valid_1's rmse: 26559.1
# [190]	training's rmse: 13002.4	valid_1's rmse: 25058.8
# [200]	training's rmse: 12799.8	valid_1's rmse: 24915
# [210]	training's rmse: 14576.6	valid_1's rmse: 25985.1
# [220]	training's rmse: 12704.2	valid_1's rmse: 24848
# [230]	training's rmse: 12821.8	valid_1's rmse: 24951.5
# [240]	training's rmse: 10823.7	valid_1's rmse: 23771.3
# [250]	training's rmse: 11153	valid_1's rmse: 23928.2
# [260]	training's rmse: 10624.8	valid_1's rmse: 23612.3
# [270]	training's rmse: 9930.4	valid_1's rmse: 23232
# [280]	training's rmse: 10043.6	valid_1's rmse: 23271.3
# [290]	training's rmse: 9607.07	valid_1's rmse: 23036
# [300]	training's rmse: 9974.53	valid_1's rmse: 23233.2
# [310]	training's rmse: 10943.9	valid_1's rmse: 23749.9
# [320]	training's rmse: 9923.08	valid_1's rmse: 23173.3
# [330]	training's rmse: 9771.57	valid_1's rmse: 23117.7
# [340]	training's rmse: 10628.9	valid_1's rmse: 23578.7
# [350]	training's rmse: 9517.06	valid_1's rmse: 22989.4
# [360]	training's rmse: 9346.51	valid_1's rmse: 22880.7
# [370]	training's rmse: 9233.39	valid_1's rmse: 22821.9
# [380]	training's rmse: 8864.77	valid_1's rmse: 22674.4
# [390]	training's rmse: 8320.12	valid_1's rmse: 22417.8
# [400]	training's rmse: 7769.5	valid_1's rmse: 22130.2
# [410]	training's rmse: 7755.72	valid_1's rmse: 22137.5
# [420]	training's rmse: 7819.37	valid_1's rmse: 22183.2
# [430]	training's rmse: 7653.75	valid_1's rmse: 22100.2
# [440]	training's rmse: 7632.47	valid_1's rmse: 22088
# [450]	training's rmse: 7098	valid_1's rmse: 21875.6
# [460]	training's rmse: 7451.94	valid_1's rmse: 22060.1
# [470]	training's rmse: 7649.8	valid_1's rmse: 22141.4
# [480]	training's rmse: 7367.2	valid_1's rmse: 22035.6
# [490]	training's rmse: 6843.68	valid_1's rmse: 21848.9
# [500]	training's rmse: 6763.14	valid_1's rmse: 21810
# [510]	training's rmse: 6547.15	valid_1's rmse: 21741.5
# [520]	training's rmse: 6645.21	valid_1's rmse: 21793.7
# [530]	training's rmse: 6735.13	valid_1's rmse: 21826.2
# [540]	training's rmse: 6728.54	valid_1's rmse: 21814.2
# [550]	training's rmse: 6566.45	valid_1's rmse: 21753.5
# [560]	training's rmse: 6458.06	valid_1's rmse: 21686.9
# [570]	training's rmse: 6817.69	valid_1's rmse: 21864.3
# [580]	training's rmse: 7225.96	valid_1's rmse: 22038
# [590]	training's rmse: 7307.31	valid_1's rmse: 22087.3
# [600]	training's rmse: 7267.6	valid_1's rmse: 22060.6
# [610]	training's rmse: 7036.96	valid_1's rmse: 21933.1
# [620]	training's rmse: 6431.54	valid_1's rmse: 21677.6
# [630]	training's rmse: 6488.1	valid_1's rmse: 21693.7
# [640]	training's rmse: 6345.33	valid_1's rmse: 21644.6
# [650]	training's rmse: 6428.56	valid_1's rmse: 21696.3
# [660]	training's rmse: 6404.77	valid_1's rmse: 21675.8
# [670]	training's rmse: 6782.82	valid_1's rmse: 21832.3
# [680]	training's rmse: 6351.38	valid_1's rmse: 21677.3
# [690]	training's rmse: 6366.55	valid_1's rmse: 21647.8
# [700]	training's rmse: 6144.51	valid_1's rmse: 21567.5
# [710]	training's rmse: 6102.55	valid_1's rmse: 21580
# [720]	training's rmse: 6512.49	valid_1's rmse: 21722.8
# [730]	training's rmse: 6133.28	valid_1's rmse: 21594.9
# [740]	training's rmse: 6057.93	valid_1's rmse: 21570
# [750]	training's rmse: 5954.95	valid_1's rmse: 21529.8
# [760]	training's rmse: 5940.41	valid_1's rmse: 21521.3
# [770]	training's rmse: 5997.28	valid_1's rmse: 21556.2
# [780]	training's rmse: 6043.85	valid_1's rmse: 21581.1
# [790]	training's rmse: 5973.02	valid_1's rmse: 21554.5
# [800]	training's rmse: 6058.75	valid_1's rmse: 21592
# [810]	training's rmse: 6097.14	valid_1's rmse: 21616.4
# [820]	training's rmse: 5986.75	valid_1's rmse: 21530.4
# [830]	training's rmse: 5676.79	valid_1's rmse: 21438.4
# [840]	training's rmse: 5440.45	valid_1's rmse: 21349.4
# [850]	training's rmse: 5440.42	valid_1's rmse: 21350.1
# [860]	training's rmse: 5461.38	valid_1's rmse: 21358.3
# [870]	training's rmse: 5366.23	valid_1's rmse: 21313.8
# [880]	training's rmse: 5666.7	valid_1's rmse: 21418.1
# [890]	training's rmse: 5344.21	valid_1's rmse: 21310.4
# [900]	training's rmse: 5389.86	valid_1's rmse: 21333.8
# [910]	training's rmse: 5506.17	valid_1's rmse: 21389.1
# [920]	training's rmse: 5710.2	valid_1's rmse: 21479.7
# [930]	training's rmse: 5531.68	valid_1's rmse: 21411.4
# [940]	training's rmse: 5427.66	valid_1's rmse: 21367.2
# [950]	training's rmse: 5299.08	valid_1's rmse: 21333.1
# [960]	training's rmse: 5197.93	valid_1's rmse: 21302.3
# [970]	training's rmse: 5150.53	valid_1's rmse: 21300.7
# [980]	training's rmse: 5153.99	valid_1's rmse: 21300.6
# [990]	training's rmse: 5354.39	valid_1's rmse: 21375.9
# [1000]	training's rmse: 5161.47	valid_1's rmse: 21289.9
# [1010]	training's rmse: 4922.39	valid_1's rmse: 21208.1
# [1020]	training's rmse: 4952.54	valid_1's rmse: 21227.6
# [1030]	training's rmse: 4942.69	valid_1's rmse: 21204
# [1040]	training's rmse: 4925.12	valid_1's rmse: 21207.6
# [1050]	training's rmse: 4874.11	valid_1's rmse: 21187.4
# [1060]	training's rmse: 5087.13	valid_1's rmse: 21268.6
# [1070]	training's rmse: 5092.49	valid_1's rmse: 21277.4
# [1080]	training's rmse: 4982.49	valid_1's rmse: 21231.1
# [1090]	training's rmse: 5141.65	valid_1's rmse: 21289.7
# [1100]	training's rmse: 4923.33	valid_1's rmse: 21192.4
# [1110]	training's rmse: 5169.38	valid_1's rmse: 21288.4
# [1120]	training's rmse: 5596.35	valid_1's rmse: 21434
# [1130]	training's rmse: 5025.66	valid_1's rmse: 21239.8
# [1140]	training's rmse: 4906.46	valid_1's rmse: 21203
# [1150]	training's rmse: 4845.91	valid_1's rmse: 21173.4
# [1160]	training's rmse: 4869.94	valid_1's rmse: 21174.2
# [1170]	training's rmse: 5006.41	valid_1's rmse: 21214
# [1180]	training's rmse: 5111.28	valid_1's rmse: 21247.4
# [1190]	training's rmse: 4931.33	valid_1's rmse: 21187.3
# [1200]	training's rmse: 4826.47	valid_1's rmse: 21152
# [1210]	training's rmse: 4485.64	valid_1's rmse: 21043.4
# [1220]	training's rmse: 4395.68	valid_1's rmse: 21017.9
# [1230]	training's rmse: 4392.98	valid_1's rmse: 21014
# [1240]	training's rmse: 4623.08	valid_1's rmse: 21094.4
# [1250]	training's rmse: 4553.15	valid_1's rmse: 21076.6
# [1260]	training's rmse: 4494.74	valid_1's rmse: 21055.3
# [1270]	training's rmse: 4557.62	valid_1's rmse: 21078.7
# [1280]	training's rmse: 4681.94	valid_1's rmse: 21121.4
# [1290]	training's rmse: 4947.99	valid_1's rmse: 21206.7
# [1300]	training's rmse: 4564.34	valid_1's rmse: 21079.9
# [1310]	training's rmse: 4366.6	valid_1's rmse: 21014.7
# [1320]	training's rmse: 4472.29	valid_1's rmse: 21055.2
# [1330]	training's rmse: 4216.07	valid_1's rmse: 20987.6
# [1340]	training's rmse: 4364.87	valid_1's rmse: 21041.5
# [1350]	training's rmse: 4496.41	valid_1's rmse: 21072.1
# [1360]	training's rmse: 4268.71	valid_1's rmse: 20983.9
# [1370]	training's rmse: 4010.21	valid_1's rmse: 20900.1
# [1380]	training's rmse: 4076.76	valid_1's rmse: 20912.6
# [1390]	training's rmse: 4120.84	valid_1's rmse: 20925.8
# [1400]	training's rmse: 4032.37	valid_1's rmse: 20908.2
# [1410]	training's rmse: 4090.6	valid_1's rmse: 20920.5
# [1420]	training's rmse: 4142.89	valid_1's rmse: 20938.9
# [1430]	training's rmse: 4108.78	valid_1's rmse: 20938.2
# [1440]	training's rmse: 4230.62	valid_1's rmse: 20976
# [1450]	training's rmse: 4226.89	valid_1's rmse: 20974.1
# [1460]	training's rmse: 4019.02	valid_1's rmse: 20911.4
# [1470]	training's rmse: 4060.52	valid_1's rmse: 20943.5
# [1480]	training's rmse: 4154.47	valid_1's rmse: 20966.6
# [1490]	training's rmse: 4183.39	valid_1's rmse: 20977
# [1500]	training's rmse: 4271.41	valid_1's rmse: 21009.9
# [1510]	training's rmse: 4468.96	valid_1's rmse: 21076.5
# [1520]	training's rmse: 4401.6	valid_1's rmse: 21061.7
# [1530]	training's rmse: 4346.72	valid_1's rmse: 21020.8
# [1540]	training's rmse: 4217.61	valid_1's rmse: 20979.7
# [1550]	training's rmse: 4066.22	valid_1's rmse: 20946
# [1560]	training's rmse: 4025.71	valid_1's rmse: 20948.3
# [1570]	training's rmse: 3937.29	valid_1's rmse: 20904.9
# [1580]	training's rmse: 3755	valid_1's rmse: 20851
# [1590]	training's rmse: 3712.88	valid_1's rmse: 20828.1
# [1600]	training's rmse: 3696.09	valid_1's rmse: 20817.4
# [1610]	training's rmse: 3756.1	valid_1's rmse: 20834.3
# [1620]	training's rmse: 3907.37	valid_1's rmse: 20868.6
# [1630]	training's rmse: 3759.36	valid_1's rmse: 20802.5
# [1640]	training's rmse: 3693.4	valid_1's rmse: 20795.4
# [1650]	training's rmse: 4068.39	valid_1's rmse: 20895.2
# [1660]	training's rmse: 3787.28	valid_1's rmse: 20810.1
# [1670]	training's rmse: 3717.36	valid_1's rmse: 20787.4
# [1680]	training's rmse: 3555.19	valid_1's rmse: 20753.1
# [1690]	training's rmse: 3497.76	valid_1's rmse: 20743.2
# [1700]	training's rmse: 3452.75	valid_1's rmse: 20737.6
# [1710]	training's rmse: 3455.72	valid_1's rmse: 20742
# [1720]	training's rmse: 3503.66	valid_1's rmse: 20754.1
# [1730]	training's rmse: 3452.32	valid_1's rmse: 20734.9
# [1740]	training's rmse: 3486.66	valid_1's rmse: 20744.8
# [1750]	training's rmse: 3419.27	valid_1's rmse: 20721.5
# [1760]	training's rmse: 3449.8	valid_1's rmse: 20735.7
# [1770]	training's rmse: 3417.74	valid_1's rmse: 20723
# [1780]	training's rmse: 3437.74	valid_1's rmse: 20726.2
# [1790]	training's rmse: 3351.71	valid_1's rmse: 20694.8
# [1800]	training's rmse: 3506.77	valid_1's rmse: 20738.2
# [1810]	training's rmse: 3284.95	valid_1's rmse: 20681.5
# [1820]	training's rmse: 3223.35	valid_1's rmse: 20670.8
# [1830]	training's rmse: 3328.3	valid_1's rmse: 20702.1
# [1840]	training's rmse: 3314.2	valid_1's rmse: 20699.3
# [1850]	training's rmse: 3284.93	valid_1's rmse: 20691.8
# [1860]	training's rmse: 3358.7	valid_1's rmse: 20718.3
# [1870]	training's rmse: 3265.82	valid_1's rmse: 20686.7
# [1880]	training's rmse: 3322.44	valid_1's rmse: 20704.1
# [1890]	training's rmse: 3427.38	valid_1's rmse: 20728.1
# [1900]	training's rmse: 3211.53	valid_1's rmse: 20685.1
# [1910]	training's rmse: 3295.23	valid_1's rmse: 20702.9
# [1920]	training's rmse: 3521.97	valid_1's rmse: 20752.3
# [1930]	training's rmse: 3485.68	valid_1's rmse: 20752.9
# [1940]	training's rmse: 3260.14	valid_1's rmse: 20689.4
# [1950]	training's rmse: 3143.15	valid_1's rmse: 20666.7
# [1960]	training's rmse: 3226.61	valid_1's rmse: 20692.3
# [1970]	training's rmse: 3202.04	valid_1's rmse: 20675.8
# [1980]	training's rmse: 3172.17	valid_1's rmse: 20674.2
# [1990]	training's rmse: 3257.27	valid_1's rmse: 20694.7
# [2000]	training's rmse: 3160.35	valid_1's rmse: 20665.8
# [2010]	training's rmse: 3183.14	valid_1's rmse: 20671.2
# [2020]	training's rmse: 2991.6	valid_1's rmse: 20624.8
# [2030]	training's rmse: 2986.83	valid_1's rmse: 20623.7
# [2040]	training's rmse: 2981.65	valid_1's rmse: 20626.5
# [2050]	training's rmse: 3027.42	valid_1's rmse: 20640.4
# [2060]	training's rmse: 3024.01	valid_1's rmse: 20633.6
# [2070]	training's rmse: 3240.47	valid_1's rmse: 20686.3
# [2080]	training's rmse: 3019.93	valid_1's rmse: 20632.1
# [2090]	training's rmse: 2907.33	valid_1's rmse: 20600.2
# [2100]	training's rmse: 2839.9	valid_1's rmse: 20587.6
# [2110]	training's rmse: 2928.91	valid_1's rmse: 20610.2
# [2120]	training's rmse: 2969.1	valid_1's rmse: 20616.1
# [2130]	training's rmse: 3046.64	valid_1's rmse: 20621.8
# [2140]	training's rmse: 2980.73	valid_1's rmse: 20608.5
# [2150]	training's rmse: 2940.29	valid_1's rmse: 20601.1
# [2160]	training's rmse: 2872.2	valid_1's rmse: 20591.1
# [2170]	training's rmse: 2909.68	valid_1's rmse: 20592.6
# [2180]	training's rmse: 2822.62	valid_1's rmse: 20567.2
# [2190]	training's rmse: 2817.24	valid_1's rmse: 20562
# [2200]	training's rmse: 2737.66	valid_1's rmse: 20547.7
# [2210]	training's rmse: 2850.75	valid_1's rmse: 20576
# [2220]	training's rmse: 2792.71	valid_1's rmse: 20560.3
# [2230]	training's rmse: 2898.58	valid_1's rmse: 20577.6
# [2240]	training's rmse: 2883.33	valid_1's rmse: 20576.2
# [2250]	training's rmse: 2743.44	valid_1's rmse: 20543.4
# [2260]	training's rmse: 2600.89	valid_1's rmse: 20505.4
# [2270]	training's rmse: 2650.62	valid_1's rmse: 20519.4
# [2280]	training's rmse: 2697.66	valid_1's rmse: 20528.1
# [2290]	training's rmse: 2581.74	valid_1's rmse: 20500.6
# [2300]	training's rmse: 2587.79	valid_1's rmse: 20500.2
# [2310]	training's rmse: 2631.32	valid_1's rmse: 20508.3
# [2320]	training's rmse: 2593.63	valid_1's rmse: 20492.1
# [2330]	training's rmse: 2559.47	valid_1's rmse: 20478.5
# [2340]	training's rmse: 2565.09	valid_1's rmse: 20483.7
# [2350]	training's rmse: 2543.23	valid_1's rmse: 20474.6
# [2360]	training's rmse: 2454.97	valid_1's rmse: 20458.5
# [2370]	training's rmse: 2470.67	valid_1's rmse: 20463.7
# [2380]	training's rmse: 2447.95	valid_1's rmse: 20462
# [2390]	training's rmse: 2429.56	valid_1's rmse: 20457.2
# [2400]	training's rmse: 2465.32	valid_1's rmse: 20473.1
# [2410]	training's rmse: 2461.86	valid_1's rmse: 20467.5
# [2420]	training's rmse: 2460.63	valid_1's rmse: 20462.5
# [2430]	training's rmse: 2589.66	valid_1's rmse: 20488.2
# [2440]	training's rmse: 2548.76	valid_1's rmse: 20473.1
# [2450]	training's rmse: 2529.46	valid_1's rmse: 20467.3
# [2460]	training's rmse: 2435.97	valid_1's rmse: 20457.1
# [2470]	training's rmse: 2439.72	valid_1's rmse: 20454
# [2480]	training's rmse: 2457.78	valid_1's rmse: 20453.5
# [2490]	training's rmse: 2576.33	valid_1's rmse: 20478
# [2500]	training's rmse: 2483.25	valid_1's rmse: 20455.7
# [2510]	training's rmse: 2391.91	valid_1's rmse: 20448.2
# [2520]	training's rmse: 2406.99	valid_1's rmse: 20453.5
# [2530]	training's rmse: 2455.19	valid_1's rmse: 20459
# [2540]	training's rmse: 2527.41	valid_1's rmse: 20472.8
# [2550]	training's rmse: 2596.93	valid_1's rmse: 20489.3
# [2560]	training's rmse: 2569.91	valid_1's rmse: 20485.3
# [2570]	training's rmse: 2555.21	valid_1's rmse: 20485.6
# [2580]	training's rmse: 2512.58	valid_1's rmse: 20471.4
# [2590]	training's rmse: 2479.19	valid_1's rmse: 20466.8
# [2600]	training's rmse: 2417.26	valid_1's rmse: 20454.3
# [2610]	training's rmse: 2440.42	valid_1's rmse: 20458.2
# [2620]	training's rmse: 2462.58	valid_1's rmse: 20457.4
# [2630]	training's rmse: 2402.55	valid_1's rmse: 20450.2
# [2640]	training's rmse: 2390.94	valid_1's rmse: 20446.3
# [2650]	training's rmse: 2460.95	valid_1's rmse: 20466
# [2660]	training's rmse: 2387.31	valid_1's rmse: 20446.6
# [2670]	training's rmse: 2562.08	valid_1's rmse: 20483.6
# [2680]	training's rmse: 2452.41	valid_1's rmse: 20458.1
# [2690]	training's rmse: 2377.19	valid_1's rmse: 20441.5
# [2700]	training's rmse: 2303.87	valid_1's rmse: 20428.9
# [2710]	training's rmse: 2296.11	valid_1's rmse: 20434.4
# [2720]	training's rmse: 2371	valid_1's rmse: 20450.3
# [2730]	training's rmse: 2539.41	valid_1's rmse: 20478.9
# [2740]	training's rmse: 2594.97	valid_1's rmse: 20491.4
# [2750]	training's rmse: 2486.06	valid_1's rmse: 20473.3
# [2760]	training's rmse: 2602.85	valid_1's rmse: 20498.9
# [2770]	training's rmse: 2625.52	valid_1's rmse: 20501.9
# [2780]	training's rmse: 2464.01	valid_1's rmse: 20463.2
# [2790]	training's rmse: 2514.04	valid_1's rmse: 20475.8
# [2800]	training's rmse: 2421.74	valid_1's rmse: 20449.6
# [2810]	training's rmse: 2441.76	valid_1's rmse: 20455.2
# [2820]	training's rmse: 2407.66	valid_1's rmse: 20443.3
# [2830]	training's rmse: 2414.98	valid_1's rmse: 20450.7
# [2840]	training's rmse: 2427.24	valid_1's rmse: 20453.5
# [2850]	training's rmse: 2367.59	valid_1's rmse: 20450.4
# [2860]	training's rmse: 2394.89	valid_1's rmse: 20457.6
# [2870]	training's rmse: 2334.64	valid_1's rmse: 20448.1
# [2880]	training's rmse: 2267.33	valid_1's rmse: 20438
# [2890]	training's rmse: 2268.11	valid_1's rmse: 20440.1
# [2900]	training's rmse: 2357.82	valid_1's rmse: 20450.6
# [2910]	training's rmse: 2365.39	valid_1's rmse: 20446.8
# [2920]	training's rmse: 2320.86	valid_1's rmse: 20435.7
# [2930]	training's rmse: 2332.47	valid_1's rmse: 20438.8
# [2940]	training's rmse: 2263.5	valid_1's rmse: 20427.3
# [2950]	training's rmse: 2245.37	valid_1's rmse: 20425.5
# [2960]	training's rmse: 2301.18	valid_1's rmse: 20437.6
# [2970]	training's rmse: 2168.81	valid_1's rmse: 20421.9
# [2980]	training's rmse: 2146.11	valid_1's rmse: 20416.7
# [2990]	training's rmse: 2124.02	valid_1's rmse: 20410.5
# [3000]	training's rmse: 2130.69	valid_1's rmse: 20408

# %%
df = pd.read_csv('test.csv')
id = df['id']
y_pred = pd.DataFrame(y_pred)
result = pd.concat([id, y_pred],axis=1)
result.to_csv('DART_cs_nLDKS_bld_result.csv',index=False)

# %%
LGBM_cs2_nLD_bld_results = pd.read_csv('LGBM_cs2_nLD_bld_result.csv')
DART_cs_nLDKS_bld_results = pd.read_csv('DART_cs_nLDKS_bld_result.csv')
X = pd.concat([LGBM_cs2_nLD_bld_results['0'],DART_cs_nLDKS_bld_results['0']],axis=1)
X.corr()
# Out:
#           0         0
# 0  1.000000  0.991778
# 0  0.991778  1.000000
